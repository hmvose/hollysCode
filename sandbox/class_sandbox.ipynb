# %%
# import the necessary modules
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# extra packages for interactive plots
import holoviews as hv
import panel as pn
pn.extension('mathjax')
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
#start on problem 6.3
def DE_sys(x,y):
    a = 5
    alpha_x = 3
    alpha_y = 4
    n = 3
    dx_dt = a + x*(1/(1+x**n)-alpha_x*y)
    dy_dt = x - alpha_y*y
    
    return dx_dt, dy_dt

# %%
portrait = pp.PhasePortrait2D(DE2s, Range=[(-2, 2), (-2, 2)], 
                              xlabel="X", ylabel="Y", Title=" ", color="gray", MeshDim = 30)

x = np.linspace(-2,2,30)
y = np.linspace(-2,2,30)

null_x =  
null_y = x/alpha_y

plt.plot(null_x, y, linewidth=3);
plt.plot(x, null_y, linewidth=3);
plt.legend(["null_x","null_y"], loc="lower right")
portrait.plot();
# Out:
#   Input In [2]
#     null_x =
#              ^
# SyntaxError: invalid syntax

# %%
#start on HW 4

k_time = np.zeros(50)
i = 0

while i < 25:
    k_time[i] += 5
    k_time[i+1] = k_time[i]
    i += 1

while i < 49:
    if k_time[i] == 0:
        break;
    k_time[i] -= 5
    print(k_time[i])
    k_time[i+1] = k_time[i]
    i += 1
    
k_time[49] = 0
# Out:
# 120.0
# 115.0
# 110.0
# 105.0
# 100.0
# 95.0
# 90.0
# 85.0
# 80.0
# 75.0
# 70.0
# 65.0
# 60.0
# 55.0
# 50.0
# 45.0
# 40.0
# 35.0
# 30.0
# 25.0
# 20.0
# 15.0
# 10.0
# 5.0

# %%
plt.plot(k_time[0:50])

# %%
#trying to recreate graphs yeehoooooo

Z = np.linspace(0, 1.25, 50)
L = [0.1, 0.6, 5]

beta = 5
K = 2
n = 3
alpha = 2
Z_wt = 1
eta_o = 0.02
delta = 0.17
M = (beta * (K**n)/(K**n + Z**n) - alpha*Z) * Z_wt
K_y = 0.4


for num in L:
    g = -(eta_o*Z)/(1-(Z/M)) + delta*(Z*num)/(K_y+num)

    plt.plot(Z, g)

# %%
def growth_rate(eta, M, delta, K_y):
    g = -(eta_o*Z)/(1-(Z/M)) + delta*(Z*5)/(K_y+5)

# %%
y = np.linspace(0,10,50)

g_y = np.zeros(50)

betas = [0.1,0.5,0.9,2]

b = 0.5

for beta in betas:
    for num in range(len(y)):
        g_y[num] = np.exp(-b*y[num]**2) - beta
    plt.plot(y,g_y)

# %%
y_har = np.linspace(0,10,30)

harv = np.zeros(30)

a=2
h=5

for i in range(len(y_har)):
    harv[i] = h*(y_har[i]/(a+y_har[i]))
    
plt.plot(y_har,harv)
